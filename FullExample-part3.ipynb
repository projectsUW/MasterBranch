# %% [markdown]
# <center><img src="http://i.imgur.com/sSaOozN.png" width="500"></center>
#
# ## Course: Computational Thinking for Governance Analytics
#
# ### Prof. José Manuel Magallanes, PhD
# * Visiting Professor of Computational Policy at Evans School of Public Policy and Governance, and eScience Institute Senior Data Science Fellow, University of Washington.
# * Professor of Government and Political Methodology, Pontificia Universidad Católica del Perú.
#
# _____
#
# # Full example - Part_3

# %% [markdown]
# ## The DEMOCRACY INDEX data:

# %%
import pandas as pd
link2= "https://en.wikipedia.org/wiki/Democracy_Index" 

# getting the data frame in one step:
demos=pd.read_html(link2,header=0,flavor='bs4',attrs={'class': 'wikitable sortable'})

# %% [markdown]
# Let's see:

# %%
demos[4]
# Out:
#                  Rank            Δ Rank                           Country  \
# 0    Full democracies  Full democracies                  Full democracies
# 1                   1               NaN                            Norway
# 2                   2               NaN                           Iceland
# 3                   3               NaN                            Sweden
# 4                   4               NaN                       New Zealand
# ..                ...               ...                               ...
# 166               163               NaN                              Chad
# 167               164               NaN                             Syria
# 168               165               NaN          Central African Republic
# 169               166               NaN  Democratic Republic of the Congo
# 170               167               NaN                       North Korea
#
#           Regime type Elec­toral pro­cess and plura­lism  \
# 0    Full democracies                   Full democracies
# 1      Full democracy                              10.00
# 2      Full democracy                              10.00
# 3      Full democracy                               9.58
# 4      Full democracy                              10.00
# ..                ...                                ...
# 166     Authoritarian                               0.00
# 167     Authoritarian                               0.00
# 168     Authoritarian                               1.25
# 169     Authoritarian                               0.00
# 170     Authoritarian                               0.00
#
#     Func­tioning of govern­ment Poli­tical partici­pation Poli­tical cul­ture  \
# 0              Full democracies          Full democracies    Full democracies
# 1                          9.64                     10.00               10.00
# 2                          8.57                      8.89               10.00
# 3                          9.29                      8.33               10.00
# 4                          8.93                      8.89                8.75
# ..                          ...                       ...                 ...
# 166                        0.00                      1.67                3.75
# 167                        0.00                      2.78                4.38
# 168                        0.00                      1.11                1.88
# 169                        0.00                      1.67                3.13
# 170                        2.50                      1.67                1.25
#
#      Civil liber­ties     Overall score           Δ Score
# 0    Full democracies  Full democracies  Full democracies
# 1                9.41              9.81              0.06
# 2                9.41              9.37              0.21
# 3                9.12              9.26              0.13
# 4                9.71              9.25              0.01
# ..                ...               ...               ...
# 166              2.35              1.55              0.06
# 167              0.00              1.43               NaN
# 168              2.35              1.32               NaN
# 169              0.88              1.13               NaN
# 170              0.00              1.08               NaN
#
# [171 rows x 11 columns]

# %%
demo=demos[4]

# %% [markdown]
# ### - Cleaning

# %%
demo.columns
# Out:
# Index(['Rank', 'Δ Rank', 'Country', 'Regime type',
#        'Elec­toral pro­cess and plura­lism', 'Func­tioning of govern­ment',
#        'Poli­tical partici­pation', 'Poli­tical cul­ture', 'Civil liber­ties',
#        'Overall score', 'Δ Score'],
#       dtype='object')

# %% [markdown]
# Keep some columns:

# %%
demo=demo.iloc[:,2:-1] #from the third up to the penultimate

# %%
#check columns as a list
demo.columns.to_list()
# Out:
# ['Country',
#  'Regime type',
#  'Elec\xadtoral pro\xadcess and plura\xadlism',
#  'Func\xadtioning of govern\xadment',
#  'Poli\xadtical partici\xadpation',
#  'Poli\xadtical cul\xadture',
#  'Civil liber\xadties',
#  'Overall score']

# %% [markdown]
# Get rid of spaces one or more spaces (\s+) and characters  that are not alphanumeric (\W):

# %%
demo.columns.str.replace('\W|\s+',"",regex=True)
# Out:
# Index(['Country', 'Regimetype', 'Electoralprocessandpluralism',
#        'Functioningofgovernment', 'Politicalparticipation', 'Politicalculture',
#        'Civilliberties', 'Overallscore'],
#       dtype='object')

# %% [markdown]
# Replacing:

# %%
# Simplifying column names to facilitate further work:
demo.columns=demo.columns.str.replace('\W|\s+',"",regex=True)

# %% [markdown]
# Check if we have some strange value in the categorical columns:

# %%
# see 
demo.Regimetype.value_counts()
# Out:
# Authoritarian            57
# Flawed democracy         52
# Hybrid regime            35
# Full democracy           23
# Authoritarian regimes     1
# Hybrid regimes            1
# Full democracies          1
# Flawed democracies        1
# Name: Regimetype, dtype: int64

# %% [markdown]
# The last four values are not ok. Those values in the cells will appear as missing values during formatting.

# %% [markdown]
# ### - Formatting

# %%
demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country                       171 non-null    object
#  1   Regimetype                    171 non-null    object
#  2   Electoralprocessandpluralism  171 non-null    object
#  3   Functioningofgovernment       171 non-null    object
#  4   Politicalparticipation        171 non-null    object
#  5   Politicalculture              171 non-null    object
#  6   Civilliberties                171 non-null    object
#  7   Overallscore                  171 non-null    object
# dtypes: object(8)
# memory usage: 10.8+ KB

# %% [markdown]
# Formatting the  ORDINAL variable. Creating the levels:

# %%
from pandas.api.types import CategoricalDtype

# create data type
levelsRegime = CategoricalDtype(categories=correctLevels, ordered=True)
# make the change:
demo.Regimetype=demo.Regimetype.astype(levelsRegime)

# %% [markdown]
# Formatting the numerical columns:

# %%
demo.iloc[:,2:]
# Out:
#     Electoralprocessandpluralism Functioningofgovernment  \
# 0               Full democracies        Full democracies
# 1                          10.00                    9.64
# 2                          10.00                    8.57
# 3                           9.58                    9.29
# 4                          10.00                    8.93
# ..                           ...                     ...
# 166                         0.00                    0.00
# 167                         0.00                    0.00
# 168                         1.25                    0.00
# 169                         0.00                    0.00
# 170                         0.00                    2.50
#
#     Politicalparticipation  Politicalculture    Civilliberties  \
# 0         Full democracies  Full democracies  Full democracies
# 1                    10.00             10.00              9.41
# 2                     8.89             10.00              9.41
# 3                     8.33             10.00              9.12
# 4                     8.89              8.75              9.71
# ..                     ...               ...               ...
# 166                   1.67              3.75              2.35
# 167                   2.78              4.38              0.00
# 168                   1.11              1.88              2.35
# 169                   1.67              3.13              0.88
# 170                   1.67              1.25              0.00
#
#          Overallscore
# 0    Full democracies
# 1                9.81
# 2                9.37
# 3                9.26
# 4                9.25
# ..                ...
# 166              1.55
# 167              1.43
# 168              1.32
# 169              1.13
# 170              1.08
#
# [171 rows x 6 columns]

# %%
demo.iloc[:,2:].apply(pd.to_numeric,errors='coerce')
# Out:
#      Electoralprocessandpluralism  Functioningofgovernment  \
# 0                             NaN                      NaN
# 1                           10.00                     9.64
# 2                           10.00                     8.57
# 3                            9.58                     9.29
# 4                           10.00                     8.93
# ..                            ...                      ...
# 166                          0.00                     0.00
# 167                          0.00                     0.00
# 168                          1.25                     0.00
# 169                          0.00                     0.00
# 170                          0.00                     2.50
#
#      Politicalparticipation  Politicalculture  Civilliberties  Overallscore
# 0                       NaN               NaN             NaN           NaN
# 1                     10.00             10.00            9.41          9.81
# 2                      8.89             10.00            9.41          9.37
# 3                      8.33             10.00            9.12          9.26
# 4                      8.89              8.75            9.71          9.25
# ..                      ...               ...             ...           ...
# 166                    1.67              3.75            2.35          1.55
# 167                    2.78              4.38            0.00          1.43
# 168                    1.11              1.88            2.35          1.32
# 169                    1.67              3.13            0.88          1.13
# 170                    1.67              1.25            0.00          1.08
#
# [171 rows x 6 columns]

# %%
#making the change
demo.iloc[:,2:]=demo.iloc[:,2:].apply(pd.to_numeric,errors='coerce')

# %% [markdown]
# Verifying:

# %%
demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country                       171 non-null    object
#  1   Regimetype                    167 non-null    category
#  2   Electoralprocessandpluralism  167 non-null    float64
#  3   Functioningofgovernment       167 non-null    float64
#  4   Politicalparticipation        167 non-null    float64
#  5   Politicalculture              167 non-null    float64
#  6   Civilliberties                167 non-null    float64
#  7   Overallscore                  167 non-null    float64
# dtypes: category(1), float64(6), object(1)
# memory usage: 9.8+ KB

# %% [markdown]
# Get rid of missing values:

# %%
demo.dropna().reset_index(drop=True)
# Out:
#                               Country      Regimetype  \
# 0                              Norway  Full democracy
# 1                             Iceland  Full democracy
# 2                              Sweden  Full democracy
# 3                         New Zealand  Full democracy
# 4                              Canada  Full democracy
# ..                                ...             ...
# 162                              Chad   Authoritarian
# 163                             Syria   Authoritarian
# 164          Central African Republic   Authoritarian
# 165  Democratic Republic of the Congo   Authoritarian
# 166                       North Korea   Authoritarian
#
#      Electoralprocessandpluralism  Functioningofgovernment  \
# 0                           10.00                     9.64
# 1                           10.00                     8.57
# 2                            9.58                     9.29
# 3                           10.00                     8.93
# 4                            9.58                     8.93
# ..                            ...                      ...
# 162                          0.00                     0.00
# 163                          0.00                     0.00
# 164                          1.25                     0.00
# 165                          0.00                     0.00
# 166                          0.00                     2.50
#
#      Politicalparticipation  Politicalculture  Civilliberties  Overallscore
# 0                     10.00             10.00            9.41          9.81
# 1                      8.89             10.00            9.41          9.37
# 2                      8.33             10.00            9.12          9.26
# 3                      8.89              8.75            9.71          9.25
# 4                      8.89              9.38            9.41          9.24
# ..                      ...               ...             ...           ...
# 162                    1.67              3.75            2.35          1.55
# 163                    2.78              4.38            0.00          1.43
# 164                    1.11              1.88            2.35          1.32
# 165                    1.67              3.13            0.88          1.13
# 166                    1.67              1.25            0.00          1.08
#
# [167 rows x 8 columns]

# %%
finaldemo=demo.dropna().reset_index(drop=True)

# %%
finaldemo.to_csv('finaldemo.csv',index=False)
