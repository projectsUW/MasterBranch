# %% [markdown]
# <center><img src="http://i.imgur.com/sSaOozN.png" width="500"></center>
#
# ## Course: Computational Thinking for Governance Analytics
#
# ### Prof. José Manuel Magallanes, PhD
# * Visiting Professor of Computational Policy at Evans School of Public Policy and Governance, and eScience Institute Senior Data Science Fellow, University of Washington.
# * Professor of Government and Political Methodology, Pontificia Universidad Católica del Perú.
#
# _____
#
# # Full example - END

# %% [markdown]
# # INTEGRATING

# %% [markdown]
# Read clean data:

# %%
import pandas as pd

kw=pd.read_csv('kw_pop.csv')
hdi=pd.read_csv('hdi.csv')
demo=pd.read_csv('finaldemo.csv')

# %%
demo.merge(hdi)
# Out:
#                       Country      Regimetype  Electoralprocessandpluralism  \
# 0                      Norway  Full democracy                         10.00
# 1                     Iceland  Full democracy                         10.00
# 2                      Sweden  Full democracy                          9.58
# 3                 New Zealand  Full democracy                         10.00
# 4                      Canada  Full democracy                          9.58
# ..                        ...             ...                           ...
# 142                Tajikistan   Authoritarian                          0.00
# 143         Equatorial Guinea   Authoritarian                          0.00
# 144              Turkmenistan   Authoritarian                          0.00
# 145                      Chad   Authoritarian                          0.00
# 146  Central African Republic   Authoritarian                          1.25
#
#      Functioningofgovernment  Politicalparticipation  Politicalculture  \
# 0                       9.64                   10.00             10.00
# 1                       8.57                    8.89             10.00
# 2                       9.29                    8.33             10.00
# 3                       8.93                    8.89              8.75
# 4                       8.93                    8.89              9.38
# ..                       ...                     ...               ...
# 142                     2.21                    2.22              4.38
# 143                     0.43                    3.33              4.38
# 144                     0.79                    2.22              5.00
# 145                     0.00                    1.67              3.75
# 146                     0.00                    1.11              1.88
#
#      Civilliberties  Overallscore       HDI      LE        EYS        MYS  \
# 0              9.41          9.81  0.953688  82.271  18.060820  12.566818
# 1              9.41          9.37  0.938474  82.855  19.174510  12.536661
# 2              9.12          9.26  0.936628  82.654  18.832230  12.426049
# 3              9.71          9.25  0.920886  82.145  18.837600  12.678166
# 4              9.41          9.24  0.922111  82.315  16.091440  13.315363
# ..              ...           ...       ...     ...        ...        ...
# 142            0.88          1.94  0.656039  70.879  11.407860  10.671672
# 143            1.47          1.92  0.588422  58.402   9.200000   5.550891
# 144            0.59          1.72  0.710131  68.073  10.889331   9.780000
# 145            2.35          1.55  0.401176  53.977   7.465364   2.409497
# 146            2.35          1.32  0.380662  52.805   7.568360   4.282000
#
#               GNI
# 0    68058.616130
# 1    47566.454670
# 2    47955.447240
# 3    35107.500230
# 4    43602.249290
# ..            ...
# 142   3482.378737
# 143  17795.541590
# 144  16407.470460
# 145   1715.568235
# 146    776.675996
#
# [147 rows x 13 columns]

# %%
testmerge=demo.merge(hdi,how='outer',indicator=True)
testmerge
# Out:
#          Country      Regimetype  Electoralprocessandpluralism  \
# 0         Norway  Full democracy                         10.00
# 1        Iceland  Full democracy                         10.00
# 2         Sweden  Full democracy                          9.58
# 3    New Zealand  Full democracy                         10.00
# 4         Canada  Full democracy                          9.58
# ..           ...             ...                           ...
# 210       Monaco             NaN                           NaN
# 211        Nauru             NaN                           NaN
# 212   San Marino             NaN                           NaN
# 213      Somalia             NaN                           NaN
# 214       Tuvalu             NaN                           NaN
#
#      Functioningofgovernment  Politicalparticipation  Politicalculture  \
# 0                       9.64                   10.00             10.00
# 1                       8.57                    8.89             10.00
# 2                       9.29                    8.33             10.00
# 3                       8.93                    8.89              8.75
# 4                       8.93                    8.89              9.38
# ..                       ...                     ...               ...
# 210                      NaN                     NaN               NaN
# 211                      NaN                     NaN               NaN
# 212                      NaN                     NaN               NaN
# 213                      NaN                     NaN               NaN
# 214                      NaN                     NaN               NaN
#
#      Civilliberties  Overallscore       HDI      LE       EYS        MYS  \
# 0              9.41          9.81  0.953688  82.271  18.06082  12.566818
# 1              9.41          9.37  0.938474  82.855  19.17451  12.536661
# 2              9.12          9.26  0.936628  82.654  18.83223  12.426049
# 3              9.71          9.25  0.920886  82.145  18.83760  12.678166
# 4              9.41          9.24  0.922111  82.315  16.09144  13.315363
# ..              ...           ...       ...     ...       ...        ...
# 210             NaN           NaN       NaN     NaN       NaN        NaN
# 211             NaN           NaN       NaN     NaN  11.25936        NaN
# 212             NaN           NaN       NaN     NaN  15.11120        NaN
# 213             NaN           NaN       NaN  57.068       NaN        NaN
# 214             NaN           NaN       NaN     NaN  12.30895        NaN
#
#               GNI      _merge
# 0    68058.616130        both
# 1    47566.454670        both
# 2    47955.447240        both
# 3    35107.500230        both
# 4    43602.249290        both
# ..            ...         ...
# 210           NaN  right_only
# 211  17312.587930  right_only
# 212           NaN  right_only
# 213           NaN  right_only
# 214   5408.949247  right_only
#
# [215 rows x 14 columns]

# %%
namesHDIOut=testmerge[testmerge._merge=='right_only'].Country.sort_values().to_list()
namesHDIOut
# Out:
# ['Andorra',
#  'Antigua and Barbuda',
#  'Bahamas',
#  'Barbados',
#  'Belize',
#  'Bolivia (Plurinational State of)',
#  'Brunei Darussalam',
#  'Cabo Verde',
#  'Congo',
#  'Congo (Democratic Republic of the)',
#  'Czechia',
#  "Côte d'Ivoire",
#  'Dominica',
#  'Eswatini (Kingdom of)',
#  'Grenada',
#  'Hong Kong, China (SAR)',
#  'Iran (Islamic Republic of)',
#  'Kiribati',
#  "Korea (Democratic People's Rep. of)",
#  'Korea (Republic of)',
#  "Lao People's Democratic Republic",
#  'Liechtenstein',
#  'Maldives',
#  'Marshall Islands',
#  'Micronesia (Federated States of)',
#  'Moldova (Republic of)',
#  'Monaco',
#  'Nauru',
#  'Palau',
#  'Palestine, State of',
#  'Russian Federation',
#  'Saint Kitts and Nevis',
#  'Saint Lucia',
#  'Saint Vincent and the Grenadines',
#  'Samoa',
#  'San Marino',
#  'Sao Tome and Principe',
#  'Seychelles',
#  'Solomon Islands',
#  'Somalia',
#  'South Sudan',
#  'Syrian Arab Republic',
#  'Tanzania (United Republic of)',
#  'Tonga',
#  'Tuvalu',
#  'Vanuatu',
#  'Venezuela (Bolivarian Republic of)',
#  'Viet Nam']

# %%
namesDEMOOut=testmerge[testmerge._merge=='left_only'].Country.sort_values().to_list()
namesDEMOOut
# Out:
# ['Bolivia',
#  'Cape Verde',
#  'Czech Republic',
#  'Democratic Republic of the Congo',
#  'Eswatini',
#  'Hong Kong',
#  'Iran',
#  'Ivory Coast',
#  'Laos',
#  'Moldova',
#  'North Korea',
#  'Palestine',
#  'Republic of the Congo',
#  'Russia',
#  'South Korea',
#  'Syria',
#  'Taiwan',
#  'Tanzania',
#  'Venezuela',
#  'Vietnam']

# %% [markdown]
# Recovering some data:

# %%
list((enumerate(namesHDIOut)))
# Out:
# [(0, 'Andorra'),
#  (1, 'Antigua and Barbuda'),
#  (2, 'Bahamas'),
#  (3, 'Barbados'),
#  (4, 'Belize'),
#  (5, 'Bolivia (Plurinational State of)'),
#  (6, 'Brunei Darussalam'),
#  (7, 'Cabo Verde'),
#  (8, 'Congo'),
#  (9, 'Congo (Democratic Republic of the)'),
#  (10, 'Czechia'),
#  (11, "Côte d'Ivoire"),
#  (12, 'Dominica'),
#  (13, 'Eswatini (Kingdom of)'),
#  (14, 'Grenada'),
#  (15, 'Hong Kong, China (SAR)'),
#  (16, 'Iran (Islamic Republic of)'),
#  (17, 'Kiribati'),
#  (18, "Korea (Democratic People's Rep. of)"),
#  (19, 'Korea (Republic of)'),
#  (20, "Lao People's Democratic Republic"),
#  (21, 'Liechtenstein'),
#  (22, 'Maldives'),
#  (23, 'Marshall Islands'),
#  (24, 'Micronesia (Federated States of)'),
#  (25, 'Moldova (Republic of)'),
#  (26, 'Monaco'),
#  (27, 'Nauru'),
#  (28, 'Palau'),
#  (29, 'Palestine, State of'),
#  (30, 'Russian Federation'),
#  (31, 'Saint Kitts and Nevis'),
#  (32, 'Saint Lucia'),
#  (33, 'Saint Vincent and the Grenadines'),
#  (34, 'Samoa'),
#  (35, 'San Marino'),
#  (36, 'Sao Tome and Principe'),
#  (37, 'Seychelles'),
#  (38, 'Solomon Islands'),
#  (39, 'Somalia'),
#  (40, 'South Sudan'),
#  (41, 'Syrian Arab Republic'),
#  (42, 'Tanzania (United Republic of)'),
#  (43, 'Tonga'),
#  (44, 'Tuvalu'),
#  (45, 'Vanuatu'),
#  (46, 'Venezuela (Bolivarian Republic of)'),
#  (47, 'Viet Nam')]

# %%
from operator import itemgetter
itemgetter(5,7,10,9,13,15,16,11,20,25,18,29,8,30,19,41,42,46,47)(namesHDIOut)
# Out:
# ('Bolivia (Plurinational State of)',
#  'Cabo Verde',
#  'Czechia',
#  'Congo (Democratic Republic of the)',
#  'Eswatini (Kingdom of)',
#  'Hong Kong, China (SAR)',
#  'Iran (Islamic Republic of)',
#  "Côte d'Ivoire",
#  "Lao People's Democratic Republic",
#  'Moldova (Republic of)',
#  "Korea (Democratic People's Rep. of)",
#  'Palestine, State of',
#  'Congo',
#  'Russian Federation',
#  'Korea (Republic of)',
#  'Syrian Arab Republic',
#  'Tanzania (United Republic of)',
#  'Venezuela (Bolivarian Republic of)',
#  'Viet Nam')

# %%
# remember no Taiwan
namesDEMOOut.remove('Taiwan')

# %%
namesDEMOOut
# Out:
# ['Bolivia',
#  'Cape Verde',
#  'Czech Republic',
#  'Democratic Republic of the Congo',
#  'Eswatini',
#  'Hong Kong',
#  'Iran',
#  'Ivory Coast',
#  'Laos',
#  'Moldova',
#  'North Korea',
#  'Palestine',
#  'Republic of the Congo',
#  'Russia',
#  'South Korea',
#  'Syria',
#  'Tanzania',
#  'Venezuela',
#  'Vietnam']

# %%
#now othe list
namesHDIOut=list(itemgetter(5,7,10,9,13,15,16,11,20,25,18,29,8,30,19,41,42,46,47)(namesHDIOut))
namesHDIOut
# Out:
# ['Bolivia (Plurinational State of)',
#  'Cabo Verde',
#  'Czechia',
#  'Congo (Democratic Republic of the)',
#  'Eswatini (Kingdom of)',
#  'Hong Kong, China (SAR)',
#  'Iran (Islamic Republic of)',
#  "Côte d'Ivoire",
#  "Lao People's Democratic Republic",
#  'Moldova (Republic of)',
#  "Korea (Democratic People's Rep. of)",
#  'Palestine, State of',
#  'Congo',
#  'Russian Federation',
#  'Korea (Republic of)',
#  'Syrian Arab Republic',
#  'Tanzania (United Republic of)',
#  'Venezuela (Bolivarian Republic of)',
#  'Viet Nam']

# %%
#prepare dict:
dict(zip(namesDEMOOut,namesHDIOut))
# Out:
# {'Bolivia': 'Bolivia (Plurinational State of)',
#  'Cape Verde': 'Cabo Verde',
#  'Czech Republic': 'Czechia',
#  'Democratic Republic of the Congo': 'Congo (Democratic Republic of the)',
#  'Eswatini': 'Eswatini (Kingdom of)',
#  'Hong Kong': 'Hong Kong, China (SAR)',
#  'Iran': 'Iran (Islamic Republic of)',
#  'Ivory Coast': "Côte d'Ivoire",
#  'Laos': "Lao People's Democratic Republic",
#  'Moldova': 'Moldova (Republic of)',
#  'North Korea': "Korea (Democratic People's Rep. of)",
#  'Palestine': 'Palestine, State of',
#  'Republic of the Congo': 'Congo',
#  'Russia': 'Russian Federation',
#  'South Korea': 'Korea (Republic of)',
#  'Syria': 'Syrian Arab Republic',
#  'Tanzania': 'Tanzania (United Republic of)',
#  'Venezuela': 'Venezuela (Bolivarian Republic of)',
#  'Vietnam': 'Viet Nam'}

# %%
demo.Country.replace(to_replace=dict(zip(namesDEMOOut,namesHDIOut)),inplace=True)

# %% [markdown]
# Redo merge:

# %%
demohdi=demo.merge(hdi)
demohdi
# Out:
#                                  Country      Regimetype  \
# 0                                 Norway  Full democracy
# 1                                Iceland  Full democracy
# 2                                 Sweden  Full democracy
# 3                            New Zealand  Full democracy
# 4                                 Canada  Full democracy
# ..                                   ...             ...
# 161                                 Chad   Authoritarian
# 162                 Syrian Arab Republic   Authoritarian
# 163             Central African Republic   Authoritarian
# 164   Congo (Democratic Republic of the)   Authoritarian
# 165  Korea (Democratic People's Rep. of)   Authoritarian
#
#      Electoralprocessandpluralism  Functioningofgovernment  \
# 0                           10.00                     9.64
# 1                           10.00                     8.57
# 2                            9.58                     9.29
# 3                           10.00                     8.93
# 4                            9.58                     8.93
# ..                            ...                      ...
# 161                          0.00                     0.00
# 162                          0.00                     0.00
# 163                          1.25                     0.00
# 164                          0.00                     0.00
# 165                          0.00                     2.50
#
#      Politicalparticipation  Politicalculture  Civilliberties  Overallscore  \
# 0                     10.00             10.00            9.41          9.81
# 1                      8.89             10.00            9.41          9.37
# 2                      8.33             10.00            9.12          9.26
# 3                      8.89              8.75            9.71          9.25
# 4                      8.89              9.38            9.41          9.24
# ..                      ...               ...             ...           ...
# 161                    1.67              3.75            2.35          1.55
# 162                    2.78              4.38            0.00          1.43
# 163                    1.11              1.88            2.35          1.32
# 164                    1.67              3.13            0.88          1.13
# 165                    1.67              1.25            0.00          1.08
#
#           HDI      LE        EYS        MYS           GNI
# 0    0.953688  82.271  18.060820  12.566818  68058.616130
# 1    0.938474  82.855  19.174510  12.536661  47566.454670
# 2    0.936628  82.654  18.832230  12.426049  47955.447240
# 3    0.920886  82.145  18.837600  12.678166  35107.500230
# 4    0.922111  82.315  16.091440  13.315363  43602.249290
# ..        ...     ...        ...        ...           ...
# 161  0.401176  53.977   7.465364   2.409497   1715.568235
# 162  0.548903  71.779   8.850100   5.100000   2725.189347
# 163  0.380662  52.805   7.568360   4.282000    776.675996
# 164  0.458730  60.368   9.702595   6.759480    800.021429
# 165       NaN  72.095  10.840575        NaN           NaN
#
# [166 rows x 13 columns]

# %%
#just adding kw_pop
demohdi.merge(kw)
# Out:
#                       Country      Regimetype  Electoralprocessandpluralism  \
# 0                      Norway  Full democracy                         10.00
# 1                     Iceland  Full democracy                         10.00
# 2                      Sweden  Full democracy                          9.58
# 3                 New Zealand  Full democracy                         10.00
# 4                      Canada  Full democracy                          9.58
# ..                        ...             ...                           ...
# 141                Tajikistan   Authoritarian                          0.00
# 142         Equatorial Guinea   Authoritarian                          0.00
# 143              Turkmenistan   Authoritarian                          0.00
# 144                      Chad   Authoritarian                          0.00
# 145  Central African Republic   Authoritarian                          1.25
#
#      Functioningofgovernment  Politicalparticipation  Politicalculture  \
# 0                       9.64                   10.00             10.00
# 1                       8.57                    8.89             10.00
# 2                       9.29                    8.33             10.00
# 3                       8.93                    8.89              8.75
# 4                       8.93                    8.89              9.38
# ..                       ...                     ...               ...
# 141                     2.21                    2.22              4.38
# 142                     0.43                    3.33              4.38
# 143                     0.79                    2.22              5.00
# 144                     0.00                    1.67              3.75
# 145                     0.00                    1.11              1.88
#
#      Civilliberties  Overallscore       HDI      LE        EYS        MYS  \
# 0              9.41          9.81  0.953688  82.271  18.060820  12.566818
# 1              9.41          9.37  0.938474  82.855  19.174510  12.536661
# 2              9.12          9.26  0.936628  82.654  18.832230  12.426049
# 3              9.71          9.25  0.920886  82.145  18.837600  12.678166
# 4              9.41          9.24  0.922111  82.315  16.091440  13.315363
# ..              ...           ...       ...     ...        ...        ...
# 141            0.88          1.94  0.656039  70.879  11.407860  10.671672
# 142            1.47          1.92  0.588422  58.402   9.200000   5.550891
# 143            0.59          1.72  0.710131  68.073  10.889331   9.780000
# 144            2.35          1.55  0.401176  53.977   7.465364   2.409497
# 145            2.35          1.32  0.380662  52.805   7.568360   4.282000
#
#               GNI       kwh_pop
# 0    68058.616130  22179.504794
# 1    47566.454670  49910.511131
# 2    47955.447240  13009.455389
# 3    35107.500230   7913.544823
# 4    43602.249290  13762.665599
# ..            ...           ...
# 141   3482.378737   1441.461642
# 142  17795.541590    542.585367
# 143  16407.470460   2704.354872
# 144   1715.568235     11.978793
# 145    776.675996     29.749996
#
# [146 rows x 14 columns]

# %% [markdown]
# Again, recovering:

# %%
testmerge2=demohdi.merge(kw,how='outer',indicator=True)

# %%
namesPOPOut=testmerge2[testmerge2._merge=='right_only'].Country.sort_values().to_list()
list((enumerate(namesPOPOut)))
# Out:
# [(0, 'American Samoa'),
#  (1, 'Andorra'),
#  (2, 'Antigua and Barbuda'),
#  (3, 'Aruba'),
#  (4, 'Bahamas, The'),
#  (5, 'Barbados'),
#  (6, 'Belize'),
#  (7, 'Bermuda'),
#  (8, 'Bolivia'),
#  (9, 'British Virgin Islands'),
#  (10, 'Brunei'),
#  (11, 'Burma'),
#  (12, 'Cayman Islands'),
#  (13, 'Congo, Democratic Republic of the'),
#  (14, 'Congo, Republic of the'),
#  (15, 'Cook Islands'),
#  (16, "Cote d'Ivoire"),
#  (17, 'Curacao'),
#  (18, 'Dominica'),
#  (19, 'Eswatini'),
#  (20, 'Falkland Islands (Islas Malvinas)'),
#  (21, 'Faroe Islands'),
#  (22, 'French Polynesia'),
#  (23, 'Gambia, The'),
#  (24, 'Gaza Strip'),
#  (25, 'Gibraltar'),
#  (26, 'Greenland'),
#  (27, 'Grenada'),
#  (28, 'Guam'),
#  (29, 'Hong Kong'),
#  (30, 'Iran'),
#  (31, 'Jersey'),
#  (32, 'Kiribati'),
#  (33, 'Korea, North'),
#  (34, 'Korea, South'),
#  (35, 'Kosovo'),
#  (36, 'Laos'),
#  (37, 'Liechtenstein'),
#  (38, 'Macau'),
#  (39, 'Maldives'),
#  (40, 'Marshall Islands'),
#  (41, 'Micronesia, Federated States of'),
#  (42, 'Moldova'),
#  (43, 'Montserrat'),
#  (44, 'Nauru'),
#  (45, 'New Caledonia'),
#  (46, 'Niue'),
#  (47, 'Northern Mariana Islands'),
#  (48, 'Puerto Rico'),
#  (49, 'Russia'),
#  (50, 'Saint Helena, Ascension, and Tristan da Cunha'),
#  (51, 'Saint Kitts and Nevis'),
#  (52, 'Saint Lucia'),
#  (53, 'Saint Pierre and Miquelon'),
#  (54, 'Saint Vincent and the Grenadines'),
#  (55, 'Samoa'),
#  (56, 'Sao Tome and Principe'),
#  (57, 'Seychelles'),
#  (58, 'Solomon Islands'),
#  (59, 'Somalia'),
#  (60, 'South Sudan'),
#  (61, 'Syria'),
#  (62, 'Taiwan'),
#  (63, 'Tanzania'),
#  (64, 'Tonga'),
#  (65, 'Turks and Caicos Islands'),
#  (66, 'Vanuatu'),
#  (67, 'Venezuela'),
#  (68, 'Vietnam'),
#  (69, 'Virgin Islands'),
#  (70, 'West Bank')]

# %%
namesHDEOut=testmerge2[testmerge2._merge=='left_only'].Country.sort_values().to_list()
namesHDEOut
# Out:
# ['Bolivia (Plurinational State of)',
#  'Congo',
#  'Congo (Democratic Republic of the)',
#  "Côte d'Ivoire",
#  'Eswatini (Kingdom of)',
#  'Gambia',
#  'Hong Kong, China (SAR)',
#  'Iran (Islamic Republic of)',
#  "Korea (Democratic People's Rep. of)",
#  'Korea (Republic of)',
#  "Lao People's Democratic Republic",
#  'Moldova (Republic of)',
#  'Myanmar',
#  'North Macedonia',
#  'Palestine, State of',
#  'Russian Federation',
#  'Syrian Arab Republic',
#  'Tanzania (United Republic of)',
#  'Venezuela (Bolivarian Republic of)',
#  'Viet Nam']

# %%
from operator import itemgetter
namesPOPOut=itemgetter(8,14,13,16,19,23,29,30,33,34,36,42,11,49,61,63,67,68)(namesPOPOut)
# NO: 'North Macedonia', 'Palestine, State of'

# %%
namesPOPOut
# Out:
# ('Bolivia',
#  'Congo, Republic of the',
#  'Congo, Democratic Republic of the',
#  "Cote d'Ivoire",
#  'Eswatini',
#  'Gambia, The',
#  'Hong Kong',
#  'Iran',
#  'Korea, North',
#  'Korea, South',
#  'Laos',
#  'Moldova',
#  'Burma',
#  'Russia',
#  'Syria',
#  'Tanzania',
#  'Venezuela',
#  'Vietnam')

# %%
namesHDEOut=[element for element in namesHDEOut if element not in ['North Macedonia', 'Palestine, State of']]
namesHDEOut
# Out:
# ['Bolivia (Plurinational State of)',
#  'Congo',
#  'Congo (Democratic Republic of the)',
#  "Côte d'Ivoire",
#  'Eswatini (Kingdom of)',
#  'Gambia',
#  'Hong Kong, China (SAR)',
#  'Iran (Islamic Republic of)',
#  "Korea (Democratic People's Rep. of)",
#  'Korea (Republic of)',
#  "Lao People's Democratic Republic",
#  'Moldova (Republic of)',
#  'Myanmar',
#  'Russian Federation',
#  'Syrian Arab Republic',
#  'Tanzania (United Republic of)',
#  'Venezuela (Bolivarian Republic of)',
#  'Viet Nam']

# %%
dict(zip(namesPOPOut,namesHDEOut))
# Out:
# {'Bolivia': 'Bolivia (Plurinational State of)',
#  'Congo, Republic of the': 'Congo',
#  'Congo, Democratic Republic of the': 'Congo (Democratic Republic of the)',
#  "Cote d'Ivoire": "Côte d'Ivoire",
#  'Eswatini': 'Eswatini (Kingdom of)',
#  'Gambia, The': 'Gambia',
#  'Hong Kong': 'Hong Kong, China (SAR)',
#  'Iran': 'Iran (Islamic Republic of)',
#  'Korea, North': "Korea (Democratic People's Rep. of)",
#  'Korea, South': 'Korea (Republic of)',
#  'Laos': "Lao People's Democratic Republic",
#  'Moldova': 'Moldova (Republic of)',
#  'Burma': 'Myanmar',
#  'Russia': 'Russian Federation',
#  'Syria': 'Syrian Arab Republic',
#  'Tanzania': 'Tanzania (United Republic of)',
#  'Venezuela': 'Venezuela (Bolivarian Republic of)',
#  'Vietnam': 'Viet Nam'}

# %%
kw.Country.replace(to_replace=dict(zip(namesPOPOut,namesHDEOut)),inplace=True)

# %%
demohdikw=demohdi.merge(kw)
demohdikw
# Out:
#                                  Country      Regimetype  \
# 0                                 Norway  Full democracy
# 1                                Iceland  Full democracy
# 2                                 Sweden  Full democracy
# 3                            New Zealand  Full democracy
# 4                                 Canada  Full democracy
# ..                                   ...             ...
# 159                                 Chad   Authoritarian
# 160                 Syrian Arab Republic   Authoritarian
# 161             Central African Republic   Authoritarian
# 162   Congo (Democratic Republic of the)   Authoritarian
# 163  Korea (Democratic People's Rep. of)   Authoritarian
#
#      Electoralprocessandpluralism  Functioningofgovernment  \
# 0                           10.00                     9.64
# 1                           10.00                     8.57
# 2                            9.58                     9.29
# 3                           10.00                     8.93
# 4                            9.58                     8.93
# ..                            ...                      ...
# 159                          0.00                     0.00
# 160                          0.00                     0.00
# 161                          1.25                     0.00
# 162                          0.00                     0.00
# 163                          0.00                     2.50
#
#      Politicalparticipation  Politicalculture  Civilliberties  Overallscore  \
# 0                     10.00             10.00            9.41          9.81
# 1                      8.89             10.00            9.41          9.37
# 2                      8.33             10.00            9.12          9.26
# 3                      8.89              8.75            9.71          9.25
# 4                      8.89              9.38            9.41          9.24
# ..                      ...               ...             ...           ...
# 159                    1.67              3.75            2.35          1.55
# 160                    2.78              4.38            0.00          1.43
# 161                    1.11              1.88            2.35          1.32
# 162                    1.67              3.13            0.88          1.13
# 163                    1.67              1.25            0.00          1.08
#
#           HDI      LE        EYS        MYS           GNI       kwh_pop
# 0    0.953688  82.271  18.060820  12.566818  68058.616130  22179.504794
# 1    0.938474  82.855  19.174510  12.536661  47566.454670  49910.511131
# 2    0.936628  82.654  18.832230  12.426049  47955.447240  13009.455389
# 3    0.920886  82.145  18.837600  12.678166  35107.500230   7913.544823
# 4    0.922111  82.315  16.091440  13.315363  43602.249290  13762.665599
# ..        ...     ...        ...        ...           ...           ...
# 159  0.401176  53.977   7.465364   2.409497   1715.568235     11.978793
# 160  0.548903  71.779   8.850100   5.100000   2725.189347    694.651712
# 161  0.380662  52.805   7.568360   4.282000    776.675996     29.749996
# 162  0.458730  60.368   9.702595   6.759480    800.021429     70.731830
# 163       NaN  72.095  10.840575        NaN           NaN    537.718494
#
# [164 rows x 14 columns]

# %% [markdown]
# ____
# ____
#
#
# ### <font color="red">Saving File to Disk</font>

# %% [markdown]
# #### For future use in Python:

# %%
demohdikw.to_pickle("demohdikw.pkl")
# you will need: DF=pd.read_pickle("demohdikw.pkl")
# or:
# from urllib.request import urlopen
# DF=pd.read_pickle(urlopen("https://..../demohdikw.pkl"),compression=None)

# %% [markdown]
# #### For future  use in R:

# %%
from rpy2.robjects import pandas2ri
pandas2ri.activate()

from rpy2.robjects.packages import importr

base = importr('base')
base.saveRDS(demohdikw,file="demohdikw.RDS")

#In R, you call it with: DF = readRDS("demohdikw.RDS")
#or, if iyou read from cloud: DF = readRDS(url("https://..../demohdikw.RDS")
# Out:
# /Users/JoseManuel/anaconda3/envs/Evans_GovAnalytics/lib/python3.7/site-packages/rpy2/robjects/vectors.py:980: UserWarning: R object inheriting from "POSIXct" but without attribute "tzone".
#   warnings.warn('R object inheriting from "POSIXct" but without '
# <rpy2.rinterface_lib.sexp.NULLType object at 0x7fd17c4b9aa0> [RTYPES.NILSXP]
